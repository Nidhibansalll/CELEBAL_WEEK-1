# %%
#import libraries
import pandas as pd

# %%
df= pd.read_csv("C:\\Users\\Admin\\Downloads\\archive\\Combined_dataset.csv")

# %%
# first 5 rows
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
# last 5 rows
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
#shape
print(df.shape)
# Out:
# (1000, 24)

# %%
print(df.columns)
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %%
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price    discount
# count  1.000000e+03  1000.0000    1000.000000     1000.00000  879.000000
# mean   1.713437e+07     3.6215      76.691000     2723.24100   53.503982
# std    3.813766e+06     1.3744     241.114263     2408.69736   18.029201
# min    5.868460e+05     0.0000       0.000000      249.00000    1.000000
# 25%    1.511501e+07     3.7000       7.000000     1399.00000   44.000000
# 50%    1.820890e+07     4.1000      17.000000     1999.00000   56.000000
# 75%    1.902737e+07     4.3000      58.000000     3299.00000   66.000000
# max    2.274707e+07     5.0000    4441.000000    22199.00000   88.000000

# %%
 df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
 df.dropna(axis=1, thresh=500)  # drop any column that does not have at least 500 non-null values.
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df['final_price'] = df['final_price'].astype(str).str.replace(r'[₹,\"\s]', '', regex=True).astype(float)

# %%
df.fillna(0)
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df[df['rating']>=4.0]
# Out:
#      product_id              title  \
# 1       9136281     Tommy Hilfiger
# 2      17633752              Lavie
# 3       1376949             F Gear
# 4      13939916          MYTRIDENT
# 5      17198778                H&M
# ..          ...                ...
# 992    11791782              CASIO
# 993    19322504                V2A
# 994     8481603  French Connection
# 996    16896006              GUESS
# 998    19280114           Fastrack
#
#                                    product_description  rating  ratings_count  \
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# 5           Beige & Tan Solid Stoneware Soap Dispenser     4.5             42
# ...

# %%
df[['product_id','title','category','rating','initial_price','discount']]
# Out:
#      product_id           title   category  rating  initial_price  discount
# 0       8376765     Lino Perros  backpacks     3.8           3995      58.0
# 1       9136281  Tommy Hilfiger  backpacks     4.5           2899      35.0
# 2      17633752           Lavie  backpacks     4.4           2999      65.0
# 3       1376949          F Gear  backpacks     4.4           1675      52.0
# 4      13939916       MYTRIDENT  bath-robe     4.7           2899      17.0
# ..          ...             ...        ...     ...            ...       ...
# 995    13698258           KREDO    watches     3.5          11890      50.0
# 996    16896006           GUESS    watches     5.0           8900      45.0
# 997     1708108        GIORDANO    watches     2.8           7950      50.0
# 998    19280114        Fastrack    watches     4.3           3295      20.0
# 999    18601682         BOLDFIT  yoga-mats     3.8            699      31.0
#
# [1000 rows x 6 columns]

# %%
df.drop_duplicates()
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
print(df.shape)
# Out:
# (1000, 24)

# %%
df['total_amount']=df['final_price']*df['ratings_count']

# %%
df[['title','final_price','ratings_count','total_amount']]
# Out:
#               title  final_price  ratings_count  total_amount
# 0       Lino Perros       3995.0             15       59925.0
# 1    Tommy Hilfiger       2899.0             67      194233.0
# 2             Lavie       2999.0            226      677774.0
# 3            F Gear       1675.0           1052     1762100.0
# 4         MYTRIDENT       2899.0             12       34788.0
# ..              ...          ...            ...           ...
# 995           KREDO      11890.0             11      130790.0
# 996           GUESS       8900.0             22      195800.0
# 997        GIORDANO       7950.0              5       39750.0
# 998        Fastrack       2636.0             17       44812.0
# 999         BOLDFIT        699.0            161      112539.0
#
# [1000 rows x 4 columns]

# %%
df['discount'] = df['discount'].fillna(0)

# %%
df['seller_name'] = df['seller_name'].fillna('Unknown')

# %%
df['seller_information'] = df['seller_information'].fillna('Unknown')

# %%
df.to_csv(r"C:\Users\Admin\Downloads\archive\Combined_dataset_CLEANED.csv",index=False)

# %%
print("FINALLY DID IT, THANK YOU!!!")
# Out:
# FINALLY DID IT, THANK YOU!!!

# %% [markdown]
# ## Brief Summary
#
# **Dataset:** Indian E-Commerce Products
# **Original:** 1000 rows × 24 columns
#
# ### What I Did
# - Loaded CSV into Pandas DataFrame
# - Explored data — shape, columns, dtypes, head/tail
# - Handled missing values — filled discount with 0, seller_name with Unknown
# - Cleaned final_price — removed ₹ symbol, converted to float
# - Filtered rows with rating >= 4.0
# - Removed duplicates — 0 found
# - Created derived column: total_amount = final_price × ratings_count
# - Saved cleaned file as Combined_dataset_CLEANED.csv
#
# ### Key Stats
#  Value |
# | Total Products = 1000 |
# | Categories = 97 |
# | Avg Final Price = ₹1,706 |
# | Duplicates = 0 |
